# %%
import numpy as np
import seaborn as sns
sns.set(color_codes=True)
import pandas as pd
import matplotlib.pyplot as plt

# %%
test_loss = [43.5553, 42.4540, 42.0784, 43.4078, 42.5582, 39.3627, 33.9645, 31.5054, 28.8851, 27.0080, 27.3870, 23.4848, 24.5719, 24.1528, 30.8612, 28.3700]

# %%
test_accuracy = [41, 41, 40, 44, 42, 41, 41, 45, 47, 48, 50, 52, 52, 53, 54, 51]

# %%
epochs = list(range(1, 17))

# %%
data = {'epoch': epochs, 'test_loss':test_loss, 'accuracy': accuracy}

# %%
df = pd.DataFrame(columns=['epoch', 'metric', 'value'])
df.loc[0] = [None, None, None]

# for i in range(len(test_loss)):
for i in range(len(test_loss)):
    epoch = i + 1
    metric = 'test_loss'
    val = test_loss[i]
    df.loc[df.index.max() + 1] = [epoch, metric, val]

for i in range(len(accuracy)):
    epoch = i + 1
    metric = 'accuracy'
    val = accuracy[i]
    df.loc[df.index.max() + 1] = [epoch, metric, val]

# %%
df
# Out:
#    epoch     metric    value
# 0   None       None      NaN
# 1      1  test_loss  43.5553
# 2      2  test_loss  42.4540
# 3      3  test_loss  42.0784
# 4      4  test_loss  43.4078
# 5      5  test_loss  42.5582
# 6      6  test_loss  39.3627
# 7      7  test_loss  33.9645
# 8      8  test_loss  31.5054
# 9      9  test_loss  28.8851
# 10    10  test_loss  27.0080
# 11    11  test_loss  27.3870
# 12    12  test_loss  23.4848
# 13    13  test_loss  24.5719
# 14    14  test_loss  24.1528
# 15    15  test_loss  30.8612
# 16    16  test_loss  28.3700
# 17     1   accuracy  41.0000
# 18     2   accuracy  41.0000
# 19     3   accuracy  40.0000
# 20     4   accuracy  44.0000
# 21     5   accuracy  42.0000
# 22     6   accuracy  41.0000
# 23     7   accuracy  41.0000
# 24     8   accuracy  45.0000
# 25     9   accuracy  47.0000
# 26    10   accuracy  48.0000
# 27    11   accuracy  50.0000
# 28    12   accuracy  52.0000
# 29    13   accuracy  52.0000
# 30    14   accuracy  53.0000
# ...

# %%
sns.set(style="darkgrid")
sns.lineplot(x='epoch', y='value', hue='metric', data=df)
plt.show()

# %%
overfeat_test_losses = [14.61335246806242, 14.836043081478197, 14.954917876574457, 14.807979490319077, 14.670156097412109, 14.16142369484415, 15.22024741659359, 13.61128351639728, 14.209113249486807, 15.117229228117028, 14.525664738246373, 14.93894762311663, 15.38496408267897, 15.117440359933036, 14.913706238415777, 15.763301709233499, 15.218737481564892, 15.42790773352798, 15.197008062868703, 15.494145934435785, 14.868436089340522, 16.04108022573043, 15.673363152328802, 15.689984193140146, 15.346903057487644, 16.13858035340601, 15.59810775445432, 16.024183997329402, 16.3708133152553, 16.34961162]

overfeat_test_accuracies = [61.49801587301586, 62.97421003033248, 57.77676546809208, 61.980640957681736, 63.08305724887364, 64.32037945048154, 62.288913184321345, 64.8469424566363, 63.78268103778305, 59.25664075153872, 63.59859896339489, 61.19744456224044, 62.5355523161646, 61.71023647554265, 62.80272476956152, 59.942548664487454, 61.7136010248256, 63.664115646258544, 61.1107466796242, 59.63536973230861, 61.70343375445421, 62.88079041140271, 63.01700680272109, 63.20756765909825, 62.43901846452874, 61.31369820655537, 62.78154725093504, 61.82151323732957, 61.13625688370583, 62.622931207114846]

overfeat_train_losses = [15.936820617987186, 13.515447390809351, 12.89010001202019, 12.368216670289332, 11.841987761672662, 11.37622540921581, 10.994893003969777, 10.813705728491959, 10.626391153919453, 9.958913367135183, 9.792905733536701, 9.547896883439044, 9.223229416049257, 8.850407008735502, 8.700821934914103, 8.50288180526422, 8.41631298259813, 8.125281746533453, 7.841424646182936, 7.870729294601752, 7.797086822743318, 7.5272656051480045, 7.413511778383839, 7.105635576832051, 6.9915385032186705, 6.871355161861498, 6.726970472141188, 6.583290329758002, 6.632781672964291, 6.476622626246238]

overfeat_train_accuracies = [58.824436051476894, 63.51119706540625, 66.73855169773537, 68.74633635921899, 70.74863522248724, 72.86432289365966, 74.11006106988248, 75.52436629413673, 76.26313241746918, 78.73858482787053, 79.62694547515977, 80.35534370674677, 81.72349037017408, 83.71008738993436, 84.13299080454696, 84.76843692022263, 85.23110293901107, 86.25647141973673, 87.76975384309573, 87.58810591336106, 87.71493543304763, 88.82803251170606, 89.54862583561561, 90.46580141796979, 90.90204155255178, 91.31005481196812, 92.07462194834649, 92.39799507465328, 92.05146214329886, 92.79384957446182]

# %%
overfeat_loss_df = pd.DataFrame(columns=['epoch', 'metric', 'value'])
overfeat_loss_df.loc[0] = [None, None, None]

# for i in range(len(test_loss)):
for i in range(len(overfeat_test_losses)):
    epoch = i + 1
    metric = 'overfeat_test_losses'
    val = overfeat_test_losses[i]
    overfeat_loss_df.loc[overfeat_loss_df.index.max() + 1] = [epoch, metric, val]

for i in range(len(overfeat_train_losses)):
    epoch = i + 1
    metric = 'overfeat_train_losses'
    val = overfeat_train_losses[i]
    overfeat_loss_df.loc[overfeat_loss_df.index.max() + 1] = [epoch, metric, val]
    
    
sns.set(style="darkgrid")
sns.lineplot(x='epoch', y='value', hue='metric', data=overfeat_loss_df)
plt.show()

# %%
overfeat_accuracy_df = pd.DataFrame(columns=['epoch', 'metric', 'value'])
overfeat_accuracy_df.loc[0] = [None, None, None]
    
for i in range(len(overfeat_test_accuracies)):
    epoch = i + 1
    metric = 'overfeat_test_accuracies'
    val = overfeat_test_accuracies[i]
    overfeat_accuracy_df.loc[overfeat_accuracy_df.index.max() + 1] = [epoch, metric, val]

for i in range(len(overfeat_train_accuracies)):
    epoch = i + 1
    metric = 'overfeat_train_accuracies'
    val = overfeat_train_accuracies[i]
    overfeat_accuracy_df.loc[overfeat_accuracy_df.index.max() + 1] = [epoch, metric, val]
    
sns.set(style="darkgrid")
sns.lineplot(x='epoch', y='value', hue='metric', data=overfeat_accuracy_df)
plt.show()
